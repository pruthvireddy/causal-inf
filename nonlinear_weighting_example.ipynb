# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Let's generate a big non-linear data set

# %%
N = 100000 

beta_x = np.random.normal(2, size=N)# 2
beta_z = 5.

z = np.random.normal(50, 10, size=N)
x = np.random.binomial(1, p=1/(1 + np.exp(-(z - z.mean())/z.std())))

y = np.random.poisson(beta_x * x + beta_z * (3 + np.sin(phi_z/0.5)))

df = pd.DataFrame({'z': z, 'x': x, 'y': y})

# %%
df.plot(y='y', x='z', kind='scatter', alpha=0.1)

# %% [markdown]
# # Look at the naive estimator

# %% [markdown]
# This is a pretty tricky relationship! Now, let's check the naive estimator. The true effect (read it above!) is $\delta = 2$.

# %%
df.groupby('x').mean()['y'][1] - df.groupby('x').mean()['y'][0]
# Out:
# 3.4203255962205805

# %% [markdown]
# Around 70% error -- that's pretty biased! This problem would be hard one to solve using linear regression. Matching or stratification would work here, but let's try our new tool: MSE minimizing ML models! Let's see if the universal function approximator can do the trick.

# %% [markdown]
# # Create a propensity model

# %%
from statsmodels.discrete.discrete_model import Logit


df['intercept'] = 1
model = Logit(endog=df['x'], 
              exog=df[['z', 'intercept']])
result = model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.598693
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      x   No. Observations:               100000
# Model:                          Logit   Df Residuals:                    99998
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 16 Feb 2021   Pseudo R-squ.:                  0.1363
# Time:                        20:53:04   Log-Likelihood:                -59869.
# converged:                       True   LL-Null:                       -69314.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# z              0.1008      0.001    120.466      0.000       0.099       0.102
# intercept     -5.0438      0.042   -118.916      0.000      -5.127      -4.961
# ==============================================================================
# """

# %%
df['propensity_score'] = df['x'] * result.predict() + \
                         (1 - df['x']) * (1 - result.predict())

# %%
from keras.layers import Dense, Input
from keras.models import Model


x_in = Input(shape=(1,))
h1 = Dense(128, activation='tanh')(x_in)
h2 = Dense(128, activation='tanh')(h1)
h3 = Dense(128, activation='tanh')(h2)
h4 = Dense(128, activation='tanh')(h3)
y = Dense(1, activation='linear')(h4)

model = Model(inputs=[x_in], outputs=[y])
model.compile('adam', loss='mse', metrics=['mse'])

# %%
# I've got a GPU, so this doesn't take too long to run. You 
# might want to reduce batch size and number of epochs on a CPU

model.fit(df[['x']], df[['y']], 
          epochs=100, batch_size=1024, 
          sample_weight=1. / df['propensity_score'])
# Out:
# Epoch 1/100
# 98/98 [==============================] - 1s 3ms/step - loss: 243.1775 - mse: 119.2919
# Epoch 2/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.8299 - mse: 30.0343
# Epoch 3/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.6586 - mse: 28.8922
# Epoch 4/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.7659 - mse: 29.2021
# Epoch 5/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.4326 - mse: 29.1194
# Epoch 6/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1209 - mse: 29.1385
# Epoch 7/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1300 - mse: 28.9537
# Epoch 8/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0250 - mse: 29.0779
# Epoch 9/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.4418 - mse: 29.1832
# Epoch 10/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8947 - mse: 28.9211
# Epoch 11/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1562 - mse: 28.9743
# Epoch 12/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.4058 - mse: 29.2241
# Epoch 13/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.6875 - mse: 29.2821
# Epoch 14/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8687 - mse: 28.9355
# Epoch 15/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1875 - mse: 29.0962
# Epoch 16/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.3328 - mse: 29.1208
# Epoch 17/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9845 - mse: 29.0338
# Epoch 18/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.5825 - mse: 29.3180
# Epoch 19/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1656 - mse: 29.0787
# Epoch 20/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2366 - mse: 29.0985
# Epoch 21/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.6311 - mse: 29.3112
# Epoch 22/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2111 - mse: 28.9758
# Epoch 23/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1923 - mse: 29.1299
# Epoch 24/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9319 - mse: 29.0764
# Epoch 25/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.4325 - mse: 29.1965
# Epoch 26/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2463 - mse: 29.1090
# Epoch 27/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.9181 - mse: 28.8723
# Epoch 28/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.3200 - mse: 29.1028
# Epoch 29/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2325 - mse: 29.2089
# Epoch 30/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.5749 - mse: 29.1314
# Epoch 31/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2733 - mse: 29.0564
# Epoch 32/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.4590 - mse: 29.2256
# Epoch 33/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2804 - mse: 29.1450
# Epoch 34/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2532 - mse: 29.0318
# Epoch 35/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.0697 - mse: 29.1693
# Epoch 36/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9412 - mse: 28.9559
# Epoch 37/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0605 - mse: 28.9860
# Epoch 38/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.3659 - mse: 29.1534
# Epoch 39/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.5324 - mse: 29.2445
# Epoch 40/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2510 - mse: 29.0431
# Epoch 41/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2940 - mse: 29.1539
# Epoch 42/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0805 - mse: 29.0995
# Epoch 43/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9259 - mse: 28.8772
# Epoch 44/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9728 - mse: 28.9807
# Epoch 45/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.5890 - mse: 29.2430
# Epoch 46/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0577 - mse: 29.1560
# Epoch 47/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0749 - mse: 29.0587
# Epoch 48/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9865 - mse: 28.9662
# Epoch 49/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9435 - mse: 29.1520
# Epoch 50/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8501 - mse: 29.0135
# Epoch 51/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.0526 - mse: 28.9627
# Epoch 52/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0511 - mse: 29.1302
# Epoch 53/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2523 - mse: 29.1562
# Epoch 54/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.5757 - mse: 29.1980
# Epoch 55/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.3780 - mse: 29.1134
# Epoch 56/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.0014 - mse: 29.0030
# Epoch 57/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.9009 - mse: 29.0375
# Epoch 58/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2184 - mse: 29.0688
# Epoch 59/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2599 - mse: 29.0882
# Epoch 60/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0320 - mse: 28.9818
# Epoch 61/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.9303 - mse: 29.0555
# Epoch 62/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0893 - mse: 28.8943
# Epoch 63/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.1458 - mse: 29.1229
# Epoch 64/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.4728 - mse: 29.2227
# Epoch 65/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2050 - mse: 29.0310
# Epoch 66/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.6653 - mse: 29.3743
# Epoch 67/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.2998 - mse: 29.1276
# Epoch 68/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.5369 - mse: 29.2548
# Epoch 69/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.1889 - mse: 29.0527
# Epoch 70/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.9016 - mse: 29.0573
# Epoch 71/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.7457 - mse: 29.2551
# Epoch 72/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.3324 - mse: 29.1463
# Epoch 73/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.4925 - mse: 29.2767
# Epoch 74/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.8250 - mse: 28.9602
# Epoch 75/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.4985 - mse: 29.2170
# Epoch 76/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.6302 - mse: 29.2080
# Epoch 77/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.0959 - mse: 29.0124
# Epoch 78/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1948 - mse: 29.1788
# Epoch 79/100
# 98/98 [==============================] - 0s 4ms/step - loss: 57.7194 - mse: 28.8228
# Epoch 80/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.4417 - mse: 29.1179
# Epoch 81/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8788 - mse: 28.9451
# Epoch 82/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.0635 - mse: 29.0758
# Epoch 83/100
# 98/98 [==============================] - 0s 4ms/step - loss: 58.1832 - mse: 29.2016
# Epoch 84/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1291 - mse: 29.1017
# Epoch 85/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8056 - mse: 28.9685
# Epoch 86/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1381 - mse: 28.9634
# Epoch 87/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.8080 - mse: 29.3471
# Epoch 88/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2653 - mse: 29.0972
# Epoch 89/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.5344 - mse: 29.0859
# Epoch 90/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.3239 - mse: 29.0961
# Epoch 91/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.5134 - mse: 28.8500
# Epoch 92/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1317 - mse: 29.0894
# Epoch 93/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.7031 - mse: 28.8976
# Epoch 94/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.1546 - mse: 29.0489
# Epoch 95/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.8455 - mse: 29.0670
# Epoch 96/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.2633 - mse: 29.0723
# Epoch 97/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.6593 - mse: 29.2937
# Epoch 98/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.5448 - mse: 29.2126
# Epoch 99/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.9444 - mse: 29.0232
# Epoch 100/100
# 98/98 [==============================] - 0s 3ms/step - loss: 58.4711 - mse: 29.2332

# %%
df_1 = df.copy()
df_1['x'] = 1
df['y_1'] = model.predict(df_1[['x']])

# %%
df_0 = df.copy()
df_0['x'] = 0
df['y_0'] = model.predict(df_0[['x']])

# %%
(df['y_1'] - df['y_0']).mean()
# Out:
# 2.0314639

# %% [markdown]
# Not bad! Just 1.5% error.

# %% [markdown]
# # Let's go doubly-robust!

# %%
x_in = Input(shape=(2,))
h1 = Dense(128, activation='tanh')(x_in)
h2 = Dense(128, activation='tanh')(h1)
h3 = Dense(128, activation='tanh')(h2)
h4 = Dense(128, activation='tanh')(h3)

y = Dense(1, activation='linear')(h4)

model = Model(inputs=[x_in], outputs=[y])
model.compile('adam', loss='mse', metrics=['mse'])

# %%
model.fit(df[['x', 'z']], df[['y']], 
          epochs=100, batch_size=1024, 
          sample_weight=1. / df['propensity_score'])
# Out:
# Epoch 1/100
# 98/98 [==============================] - 1s 3ms/step - loss: 152.2847 - mse: 77.4688
# Epoch 2/100
# 98/98 [==============================] - 0s 3ms/step - loss: 60.2421 - mse: 31.4918
# Epoch 3/100
# 98/98 [==============================] - 0s 3ms/step - loss: 59.9232 - mse: 31.5063
# Epoch 4/100
# 98/98 [==============================] - 0s 3ms/step - loss: 60.3106 - mse: 31.4613
# Epoch 5/100
# 98/98 [==============================] - 0s 3ms/step - loss: 59.8033 - mse: 31.3484
# Epoch 6/100
# 98/98 [==============================] - 0s 3ms/step - loss: 57.3817 - mse: 29.3777
# Epoch 7/100
# 98/98 [==============================] - 0s 3ms/step - loss: 47.3645 - mse: 22.9977
# Epoch 8/100
# 98/98 [==============================] - 0s 3ms/step - loss: 42.5613 - mse: 20.9260
# Epoch 9/100
# 98/98 [==============================] - 0s 4ms/step - loss: 36.4367 - mse: 18.0888
# Epoch 10/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.5387 - mse: 17.2626
# Epoch 11/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.4875 - mse: 17.2825
# Epoch 12/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.2858 - mse: 17.2080
# Epoch 13/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1761 - mse: 17.2045
# Epoch 14/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1008 - mse: 17.1441
# Epoch 15/100
# 98/98 [==============================] - 0s 4ms/step - loss: 35.0826 - mse: 17.4955
# Epoch 16/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1215 - mse: 17.0641
# Epoch 17/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.4933 - mse: 17.3756
# Epoch 18/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1589 - mse: 17.1431
# Epoch 19/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1482 - mse: 17.0766
# Epoch 20/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2002 - mse: 17.1679
# Epoch 21/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.2929 - mse: 17.2074
# Epoch 22/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0804 - mse: 17.0794
# Epoch 23/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1269 - mse: 17.1481
# Epoch 24/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.2258 - mse: 17.1647
# Epoch 25/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.7050 - mse: 16.9211
# Epoch 26/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.9609 - mse: 16.9601
# Epoch 27/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1386 - mse: 17.1283
# Epoch 28/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1027 - mse: 17.0202
# Epoch 29/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2008 - mse: 17.1130
# Epoch 30/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.3719 - mse: 17.1440
# Epoch 31/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8714 - mse: 17.0553
# Epoch 32/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0790 - mse: 17.0610
# Epoch 33/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8153 - mse: 16.8688
# Epoch 34/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8130 - mse: 16.9167
# Epoch 35/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.2881 - mse: 17.2757
# Epoch 36/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8060 - mse: 16.9926
# Epoch 37/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9986 - mse: 16.9823
# Epoch 38/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0253 - mse: 16.9786
# Epoch 39/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.6656 - mse: 16.8635
# Epoch 40/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.4227 - mse: 16.8003
# Epoch 41/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7921 - mse: 16.9409
# Epoch 42/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8047 - mse: 16.8947
# Epoch 43/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.5838 - mse: 16.8646
# Epoch 44/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9275 - mse: 17.0590
# Epoch 45/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2631 - mse: 17.1443
# Epoch 46/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7205 - mse: 16.9054
# Epoch 47/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9622 - mse: 16.9288
# Epoch 48/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8731 - mse: 17.0561
# Epoch 49/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.4801 - mse: 16.7765
# Epoch 50/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8719 - mse: 16.9335
# Epoch 51/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0138 - mse: 16.9443
# Epoch 52/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0242 - mse: 17.0504
# Epoch 53/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1147 - mse: 17.1358
# Epoch 54/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2104 - mse: 17.0146
# Epoch 55/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9480 - mse: 16.8706
# Epoch 56/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1311 - mse: 17.0281
# Epoch 57/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2595 - mse: 17.1712
# Epoch 58/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9102 - mse: 16.9537
# Epoch 59/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0351 - mse: 17.0523
# Epoch 60/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7994 - mse: 16.8508
# Epoch 61/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7200 - mse: 16.8495
# Epoch 62/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7427 - mse: 16.9502
# Epoch 63/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8550 - mse: 16.9470
# Epoch 64/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0489 - mse: 17.0005
# Epoch 65/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2077 - mse: 17.0298
# Epoch 66/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.4755 - mse: 16.8313
# Epoch 67/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.0764 - mse: 17.0004
# Epoch 68/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9037 - mse: 16.9389
# Epoch 69/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.2282 - mse: 17.0583
# Epoch 70/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.5262 - mse: 17.1863
# Epoch 71/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.7940 - mse: 16.8419
# Epoch 72/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0834 - mse: 17.0536
# Epoch 73/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8369 - mse: 16.9444
# Epoch 74/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7457 - mse: 16.9343
# Epoch 75/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.9332 - mse: 17.0415
# Epoch 76/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.6306 - mse: 16.7706
# Epoch 77/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0053 - mse: 16.9882
# Epoch 78/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.7694 - mse: 16.8869
# Epoch 79/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.9954 - mse: 16.9224
# Epoch 80/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.3493 - mse: 16.6981
# Epoch 81/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.9854 - mse: 16.9039
# Epoch 82/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0105 - mse: 16.9184
# Epoch 83/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8943 - mse: 17.0061
# Epoch 84/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1125 - mse: 17.1014
# Epoch 85/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1642 - mse: 16.9816
# Epoch 86/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8962 - mse: 16.8871
# Epoch 87/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.6929 - mse: 16.8460
# Epoch 88/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.6757 - mse: 16.8718
# Epoch 89/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.6058 - mse: 16.8130
# Epoch 90/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.8759 - mse: 16.9523
# Epoch 91/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.0429 - mse: 17.0409
# Epoch 92/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9536 - mse: 16.9314
# Epoch 93/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.8911 - mse: 16.9252
# Epoch 94/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.1213 - mse: 17.0531
# Epoch 95/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.9169 - mse: 16.9711
# Epoch 96/100
# 98/98 [==============================] - 0s 4ms/step - loss: 34.1518 - mse: 17.0857
# Epoch 97/100
# 98/98 [==============================] - 0s 3ms/step - loss: 33.7900 - mse: 16.8751
# Epoch 98/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.7976 - mse: 16.9197
# Epoch 99/100
# 98/98 [==============================] - 0s 3ms/step - loss: 34.3424 - mse: 17.1520
# Epoch 100/100
# 98/98 [==============================] - 0s 4ms/step - loss: 33.9820 - mse: 16.9198

# %% [markdown]
# Now that we've got a model for $E[Y| X, Z]$, let's apply the procedure we've learned to estimate $E[\delta]$.

# %%
df_1 = df.copy()
df_1['x'] = 1
df['y_1'] = model.predict(df_1[['x', 'z']])

# %%
df_0 = df.copy()
df_0['x'] = 0
df['y_0'] = model.predict(df_0[['x', 'z']])

# %%
(df['y_1'] - df['y_0']).mean()
# Out:
# 2.0572746

# %% [markdown]
# Not too bad! $E[\delta] = 2.03$. We're down to around 1.5% error from our original estimate with around 70% error. Let's see what the model is fitting.

# %%
df['y_pred'] = model.predict(df[['x', 'z']])
df.plot(x='z', y='y_pred', kind='scatter')

# %% [markdown]
# So it's kindof ugly, especially at the edges of the support, and a little bumpy throughout. We'd probably do better by fine-tuning the model, but this isn't bad considering how ugly the DGP is!
